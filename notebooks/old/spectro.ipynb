# %%
from matplotlib import pyplot as plt
import pandas as pd
from scipy.signal import spectrogram

# %%
import numpy as np


df = pd.DataFrame({"val": [np.sin(2 * np.pi * t) for t in range(100)]})
df
# Out:
#              val
# 0   0.000000e+00
# 1  -2.449294e-16
# 2  -4.898587e-16
# 3  -7.347881e-16
# 4  -9.797174e-16
# ..           ...
# 95 -1.952007e-15
# 96 -2.351322e-14
# 97 -4.507443e-14
# 98 -6.663564e-14
# 99  2.548998e-14
#
# [100 rows x 1 columns]

# %%
f, t, Sxx = spectrogram(
    x=df["val"],
    fs=10,
    nperseg=30,
    mode="magnitude",
)

plt.figure()
plt.pcolormesh(t, f, Sxx, shading="gouraud")
plt.title(f"Spectrogram for val")
plt.ylabel("Frequency [Hz]")
plt.xlabel("Time [sec]")
plt.colorbar(label="Magnitude")
plt.show()
